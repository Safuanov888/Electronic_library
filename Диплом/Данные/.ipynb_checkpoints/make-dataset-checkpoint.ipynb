# %%
import os
os.environ['HF_HOME'] = 'D:\\HuggingFace'
os.environ['TRANSFORMERS_CACHE'] = os.environ['HF_HOME']
os.environ['HUGGINGFACE_HUB_CACHE'] = os.environ['HF_HOME']

# %%
from warnings import filterwarnings
filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from transformers import pipeline
import re

sns.set_style('darkgrid')
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cpu'

# %%
# !pip install PyPDF2 # обработка пдф
# !pip install chonkie # чанки
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting chonkie
#   Downloading chonkie-1.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from chonkie) (4.67.1)
# Collecting numpy>=2.0.0 (from chonkie)
#   Downloading numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.3 MB/s eta 0:00:00
# Downloading chonkie-1.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 26.4 MB/s eta 0:00:0000:01
# Downloading numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 97.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy, chonkie
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.5 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed chonkie-1.4.2 numpy-2.3.5

# %% [markdown]
# # Обработка pdf

# %%
clean_data = pd.DataFrame({"Algo": [], "Analysis": [], "NN": [], "Optim": [], "SQL": []})

# %%
from PyPDF2 import PdfReader


def process_info(file):
    with open(file, "rb") as f:
        reader = PdfReader(f)
        text = ''.join([page.extract_text() for page in reader.pages])
    # Служебная информация
    text = re.sub(r'ISSN\s+\d{4}-\d{3,4}[^\n]*', '', text)
    text = re.sub(r'\d{4};\d{2}\(\d+\):\d+–\d+', '', text)

    # Авторы
    text = re.sub(r'[А-ЯЁ][а-яё]+\s+[А-ЯЁ][\.\s]+\s*[А-ЯЁ][\.\s]*', '', text)
    text = re.sub(r'[А-ЯЁ][а-яё]+\s+[А-ЯЁ][а-яё]+\s+[А-ЯЁ][\.\s]+\s*[А-ЯЁ][\.\s]*', '', text)
    text = re.sub(r'\d+[\s\w\.,–-]+(университет|институт|академия|центр)[^\n]*', '', text)

    # Сноски в квадратных скобках
    text = re.sub(r'\[\d+\]', '', text)  # [1], [2]
    text = re.sub(r'\[\d+[,-]\d+\]', '', text)  # [1-3], [4,5]
    text = re.sub(r'\[[A-Za-z]+\d*\]', '', text)  # [A1], [B]
    
    # email
    text = re.sub(r'\S+@\S+', '', text)
    
    # английские разделы 
    text = re.sub(r'Abstract[^\n]*[\s\S]*?(?=\n[А-ЯЁ]|$)', '', text)
    text = re.sub(r'Keywords[^\n]*[\s\S]*?(?=\n[А-ЯЁ]|$)', '', text)
    text = re.sub(r'For citation[^\n]*[\s\S]*?(?=\n[А-ЯЁ]|$)', '', text)
    
    # ссылки
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    text = re.sub(r'DOI:\s*\S+', '', text)
    
    # библиография
    text = re.sub(r'Список\s+источников[\s\S]*', '', text)
    text = re.sub(r'References[\s\S]*', '', text)
    
    # спец.символы
    text = text.replace('\xa0', ' ').replace('•', '')
    text = re.sub(r'-\s+', '', text)  
    text = re.sub(r'\s+', ' ', text).strip()
    text = re.sub(r'•\s*\n', '', text)
    
    # оставшиеся английские фрагменты
    text = re.sub(r'(?:[A-Za-z-]+\s){3,}[A-Za-z-]*', '', text)
    
    return text

# %%
from pathlib import Path


def make_clean_pdfs(path):
    books = Path(path)
    files_to_process = []
    for book in books.iterdir():
        files_to_process.append(str(book))

    clean_files = []
    for file in files_to_process:
        if '.pdf' in file:
            print(f'Сейчас обрабатывается: {file}')
            clean_files.append(process_info(file))
        
    return clean_files

# %% [markdown]
# ## Обработка всех классов и очистка pdf

# %%
algo_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Алгоритмы и структуры данных"
analysis_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Анализ данных"
nn_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/ИИ"
optim_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Методы оптимизации"
sql_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/SQL"

# %%
clean_data['Algo'] = make_clean_pdfs(algo_path)
print("____________DONE_____________")
clean_data['Analysis'] = make_clean_pdfs(analysis_path)
print("____________DONE_____________")
clean_data['NN'] = make_clean_pdfs(nn_path)
print("____________DONE_____________")
clean_data['Optim'] = make_clean_pdfs(optim_path)
print("____________DONE_____________")
clean_data['SQL'] = make_clean_pdfs(sql_path)
print("____________DONE_____________")
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Algoritmy_i_struktury_dannyh.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Algoritmy_i_struktury_dannyx_Konspekt_lekciy.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Dzh_Makkonell_-_Analiz_algoritmov_Vvodny_kurs_2-e_dopolnennoe_izdanie.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\txwytrupfmpl6jc1vpoxcevgi1zsx0t8.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\up.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\2699.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\32MNNPU19.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Luchko_I.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Sovremennye-tehnologii-intellektualnogo-analiza-dannyh.622755.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Макаров А.А._BOOK.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\217.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\3142.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Kron_Glubokoe-obuchenie-v-kartinkah-Vizualnyy-gid-po-iskusstvennomu-intellektu.665053.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Белая книга.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Боровская-Е.В.-Основы-искусственного-интеллекта.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\2681.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\869636.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\978-5-7996-2090-5_2017.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\Goncharov_V_A_Metody_optimizatsii.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\Каштаева С.В. Методы оптимизации  учебное пособие.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\978-5-7996-1622-9_2016.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Bazy_dannykh_Inzhiniring_nadezhnosti_2020_Leyn_Kempbell_Cheriti_Meydzhors.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Gruber.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Printsipy_organizatsii_raspredelennykh_baz_dannykh_2021_Tamer_Yocy_Patrik_Valduries.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Шилдс Уолтер SQL.pdf
# ____________DONE_____________

# %%
len(clean_data['Algo'][2])
# Out:
# 617563

# %%
clean_data.to_csv('clean_pdfs.csv', sep=',', index=False, encoding='utf-8-sig', escapechar='\\')

# %%
clean_data.shape
# Out:
# (5, 5)

# %% [markdown]
# # Создание обучающей выборки из эмбеддингов документов

# %%
text_dataset = pd.read_csv('/kaggle/input/5-classes-diplom/clean_pdfs.csv')

# %%
print(text_dataset.shape)
print(text_dataset.columns)
# Out:
# (5, 5)
# Index(['Algo', 'Analysis', 'NN', 'Optim', 'SQL'], dtype='object')

# %%
len(text_dataset['Algo'][4])
# Out:
# 208985

# %% [markdown]
# ## Чанкование

# %%
from chonkie import TokenChunker, OverlapRefinery

# %%
len(text_dataset['Algo'][0])
# Out:
# 560760

# %%
# Инициализация базового чанкировщика
chunker = TokenChunker(
    chunk_size=512,
    chunk_overlap=50
)

# Разделение текста на чанки по базовым правилам TokenChunker
chunks = chunker(text_dataset['Algo'][0])

# %%
chunks[0]
# Out:
# Chunk(text='Алгоритмы и структуры данных Новая версия для Оберона + CD Москва, 2010Никлаус Вирт Перевод с английского под редакцией доктора физ-мат. наук, УДК 32.973.26-018.2 ББК 004.438 В52 Никлаус Вирт В52 Алгоритмы и структуры данных. Новая версия для Оберона + CD / Пер. с англ. – М.: ДМК П ресс, 2010. – 272 с.: ил. ISBN 978-5-94074-584-6 В классическом учебнике тьюринговского лауреата Н.Вирта аккуратно, на тщательно подобранных примерах прорабатываются основные темы алго)ритмики – сортировка и поиск, рекурсия, дина', token_count=512, start_index=0, end_index=512)

# %%
len(chunks)
# Out:
# 1214

# %% [markdown]
# ## Загрузка модели

# %%
from transformers import AutoModel, AutoTokenizer 

model_name = "DeepPavlov/rubert-base-cased-conversational" 

model = AutoModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

inputs = tokenizer("Hello world!", return_tensors="pt")

outputs = model(**inputs)
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased-conversational were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## Анализ получения эмбеддингов

# %%
chunker = TokenChunker(
    chunk_size=512,
    chunk_overlap=50
)

# %%
embeddings = torch.mean(outputs.last_hidden_state, dim=1)
embedding_array = embeddings.detach().numpy()

# %%
embedding_array.shape

# %%
inputs = tokenizer(str(chunks[0]), return_tensors="pt")
outputs = model(**inputs)
embeddings = torch.mean(outputs.last_hidden_state, dim=1)
embedding_array = embeddings.detach().numpy()
embedding_array.shape
# Out:
# (1, 768)

# %% [markdown]
# Проставим такие метки для классов:
# - Algo - 0
# - Analysis - 1
# - NN - 2
# - Optim - 3
# - SQL - 4

# %%
classes_dict = {'Algo': 0, 'Analysis': 1, 'NN': 2, 'Optim': 3, 'SQL': 4}

# %%
def make_embeddings_from_document(document, label, device=None): 
    # Перемещаем модель на устройство (один раз, при инициализации)
    if not hasattr(make_embeddings_from_document, 'model_on_device'):
        model.to(device)
        make_embeddings_from_document.model_on_device = True
        
    embeddings = []
    labels = []
    chunks = chunker(document)  # Получаем чанки 512 на 50 перекрытия
    print(f'Общая длина: {len(chunks)}')
    
    for i in range(len(chunks)):
        # Перемещаем входные данные на GPU
        inputs = tokenizer(str(chunks[i]), return_tensors="pt").to(device)
        
        with torch.no_grad():  # Отключаем вычисление градиентов для скорости
            outputs = model(**inputs)
            embeddings_from_outputs = torch.mean(outputs.last_hidden_state, dim=1)
            
            # Перемещаем обратно на CPU для преобразования в numpy
            embedding_array = embeddings_from_outputs.cpu().numpy()

        # Засовываем в общий массив
        embeddings.append(embedding_array)
        labels.append(classes_dict[label])
        
        if i % 100 == 0:
            print(f'{i} есть👌')
            
    return embeddings, labels

# %%
embeddings, labels = make_embeddings_from_document(text_dataset['Algo'][0], 'Algo', device)
# Out:
# Общая длина: 1214
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌

# %% [markdown]
# ## Создаём массивы со всеми эмбеддингами и метками

# %%
embeddings_list = []
labels_list = []
for class_name in classes_dict:
    print(f"Обрабатываем класс: {class_name}")
    texts = text_dataset[class_name]  # Список текстов для этого класса

    for text in texts:
        embeddings, labels = make_embeddings_from_document(text, class_name, device)
        embeddings_list.extend(embeddings)
        labels_list.extend(labels)
    
    print(f'{class_name} отработал 👌')
# Out:
# Обрабатываем класс: Algo
# Общая длина: 1214
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# Общая длина: 295
# 0 есть👌
# 100 есть👌
# 200 есть👌
# Общая длина: 1337
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# 1300 есть👌
# Общая длина: 440
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# Общая длина: 453
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# Algo отработал 👌
# Обрабатываем класс: Analysis
# Общая длина: 540
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# Общая длина: 584
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# Общая длина: 423
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# Общая длина: 723
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# Общая длина: 2292
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# 1300 есть👌
# 1400 есть👌
# 1500 есть👌
# 1600 есть👌
# 1700 есть👌
# 1800 есть👌
# 1900 есть👌
# 2000 есть👌
# 2100 есть👌
# 2200 есть👌
# Analysis отработал 👌
# Обрабатываем класс: NN
# Общая длина: 337
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# Общая длина: 757
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# Общая длина: 1687
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# 1300 есть👌
# 1400 есть👌
# 1500 есть👌
# 1600 есть👌
# Общая длина: 758
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# Общая длина: 421
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# NN отработал 👌
# Обрабатываем класс: Optim
# Общая длина: 207
# 0 есть👌
# 100 есть👌
# 200 есть👌
# Общая длина: 288
# 0 есть👌
# 100 есть👌
# 200 есть👌
# Общая длина: 311
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# Общая длина: 589
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# Общая длина: 248
# 0 есть👌
# 100 есть👌
# 200 есть👌
# Optim отработал 👌
# Обрабатываем класс: SQL
# Общая длина: 485
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# Общая длина: 1547
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# 1300 есть👌
# 1400 есть👌
# 1500 есть👌
# Общая длина: 1230
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# Общая длина: 3452
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# 700 есть👌
# 800 есть👌
# 900 есть👌
# 1000 есть👌
# 1100 есть👌
# 1200 есть👌
# 1300 есть👌
# 1400 есть👌
# 1500 есть👌
# 1600 есть👌
# 1700 есть👌
# 1800 есть👌
# 1900 есть👌
# 2000 есть👌
# 2100 есть👌
# 2200 есть👌
# 2300 есть👌
# 2400 есть👌
# 2500 есть👌
# 2600 есть👌
# 2700 есть👌
# 2800 есть👌
# 2900 есть👌
# 3000 есть👌
# 3100 есть👌
# 3200 есть👌
# 3300 есть👌
# 3400 есть👌
# Общая длина: 636
# 0 есть👌
# 100 есть👌
# 200 есть👌
# 300 есть👌
# 400 есть👌
# 500 есть👌
# 600 есть👌
# SQL отработал 👌

# %%
len(labels_list)
# Out:
# 21254

# %% [markdown]
# # Сохранение в файл h5

# %%
import h5py
import numpy as np

with h5py.File('embeddings_dataset.h5', 'w') as f:
    f.create_dataset('embeddings', data=np.array(embeddings_list))
    f.create_dataset('labels', data=np.array(labels_list))

# %% [markdown]
# # Создание полного чистого датасета (11 классов)

# %%
full_clean_data = pd.DataFrame({"Algo": [], "Analysis": [], "NN": [], "Optim": [], "SQL": [],
                           'Software_engineering': [], 'CIS_design': [], 'Software_testing': [], 
                           'Project_management': [], 'Philosophy': [], 'Programming_languages': []})

# %%
software_engineering_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Программная_инженерия'

# %%
full_clean_data['Software_engineering'] = make_clean_pdfs(software_engineering_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Программная_инженерия\141-Введение_в_программную_инженерию-пособие-171011.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Программная_инженерия\38.03.05_Programmnaya_ingheneriya.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Программная_инженерия\Lipaev-Metodol-osnovy-Soft-Eng.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Программная_инженерия\MU_B1V03_ISTM_2022.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Программная_инженерия\Software Engineering of Complex Custom Software.pdf

# %%
len(full_clean_data['Software_engineering'][4])
# Out:
# 588461

# %%
cis_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Проектирование_КИС'
full_clean_data['CIS_design'] = make_clean_pdfs(cis_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Проектирование_КИС\1705.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Проектирование_КИС\fel16S061.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Проектирование_КИС\Grekoul.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Проектирование_КИС\Uchebn_posobie-Proektirovanie-raspredelennykh-IS.pdf.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Проектирование_КИС\view_3084_978-5-9775-2068-3.pdf

# %%
soft_test_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Тестирование_ПО'
full_clean_data['Software_testing'] = make_clean_pdfs(soft_test_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Тестирование_ПО\Kak_testiruyut_v_Google.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Тестирование_ПО\Nikolukin.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Тестирование_ПО\testirovanie_dot-com.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Тестирование_ПО\Кейнер К., Бах Дж., Петтикорд Б._ Тестирование программного обеспечения.(2025).pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Тестирование_ПО\Тестирование программного обеспечения.pdf

# %%
len(full_clean_data['Software_testing'][4])
# Out:
# 188745

# %%
project_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Управление_проектами'
full_clean_data['Project_management'] = make_clean_pdfs(project_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Управление_проектами\2120.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Управление_проектами\4371.pdf
# Illegal character in Name Object (b'/ABCDEE+Times New Roman \xcf\xee\xeb\xf3\xe6\xe8\xf0\xed\xfb\xe9,Bold')
# Illegal character in Name Object (b'/ABCDEE+Times New Roman \xcf\xee\xeb\xf3\xe6\xe8\xf0\xed\xfb\xe9,Bold')
# Illegal character in Name Object (b'/ABCDEE+Times New Roman \xcf\xee\xeb\xf3\xe6\xe8\xf0\xed\xfb\xe9,Bold')
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Управление_проектами\866841.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Управление_проектами\978-5-7996-1751-6_2016.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Управление_проектами\Aleshin_A.V.,_i_dr._-_Upravlenie_proektami,_fundamentalynyi_kurs,_3-e_izd._(Uchebniki_Vysshei_shkoly_ekonomiki)_-_2024.pdf

# %%
len(full_clean_data['Project_management'][4])
# Out:
# 1585467

# %%
philosophy_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Философия'
full_clean_data['Philosophy'] = make_clean_pdfs(philosophy_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Философия\2017_2_История_мировой_философии_Ч1.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Философия\osnovy_filosofii_gubin_v_d_uch__pos_2008__288s.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Философия\[philosophy]_spirkin.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Философия\Кочеров, Сидорова. Учебное пособие по философии.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Философия\Пахонина Е.В., Синицына Т.И. Философия.Учебное пособие.2022.pdf

# %%
len(full_clean_data['Philosophy'][4])
# Out:
# 944980

# %%
proga_path = 'D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Python'
full_clean_data['Python'] = make_clean_pdfs(proga_path)
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Python\978-5-19-011853-7_e-book.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Python\978-5-7996-1198-9_2014.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Python\e.metiz_-_izuchaem_python._programmirovanie_igr_vizualizaciya_dannyh_veb-prilozheniya_-_2017.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Python\Python-sysoeva-ed2-1.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Python\Язык_программирования_Python.pdf

# %%
len(full_clean_data['Python'][4])
# Out:
# 889951

# %%
algo_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Алгоритмы и структуры данных"
analysis_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Анализ данных"
nn_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/ИИ"
optim_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/Методы оптимизации"
sql_path = "D://ПРОГА/Проектики/Github/Electronic_library/Диплом/Данные/Обучающая/SQL"

# %%
full_clean_data['Algo'] = make_clean_pdfs(algo_path)
print("____________DONE_____________")
full_clean_data['Analysis'] = make_clean_pdfs(analysis_path)
print("____________DONE_____________")
full_clean_data['NN'] = make_clean_pdfs(nn_path)
print("____________DONE_____________")
full_clean_data['Optim'] = make_clean_pdfs(optim_path)
print("____________DONE_____________")
full_clean_data['SQL'] = make_clean_pdfs(sql_path)
print("____________DONE_____________")
# Out:
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Algoritmy_i_struktury_dannyh.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Algoritmy_i_struktury_dannyx_Konspekt_lekciy.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\Dzh_Makkonell_-_Analiz_algoritmov_Vvodny_kurs_2-e_dopolnennoe_izdanie.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\txwytrupfmpl6jc1vpoxcevgi1zsx0t8.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Алгоритмы и структуры данных\up.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\2699.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\32MNNPU19.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Luchko_I.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Sovremennye-tehnologii-intellektualnogo-analiza-dannyh.622755.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Анализ данных\Макаров А.А._BOOK.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\217.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\3142.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Kron_Glubokoe-obuchenie-v-kartinkah-Vizualnyy-gid-po-iskusstvennomu-intellektu.665053.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Белая книга.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\ИИ\Боровская-Е.В.-Основы-искусственного-интеллекта.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\2681.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\869636.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\978-5-7996-2090-5_2017.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\Goncharov_V_A_Metody_optimizatsii.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\Методы оптимизации\Каштаева С.В. Методы оптимизации  учебное пособие.pdf
# ____________DONE_____________
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\978-5-7996-1622-9_2016.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Bazy_dannykh_Inzhiniring_nadezhnosti_2020_Leyn_Kempbell_Cheriti_Meydzhors.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Gruber.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Printsipy_organizatsii_raspredelennykh_baz_dannykh_2021_Tamer_Yocy_Patrik_Valduries.pdf
# Сейчас обрабатывается: D:\ПРОГА\Проектики\Github\Electronic_library\Диплом\Данные\Обучающая\SQL\Шилдс Уолтер SQL.pdf
# ____________DONE_____________

# %%
full_clean_data.to_csv('full_clean_pdfs.csv', sep=',', index=False, encoding='utf-8-sig', escapechar='\\')

# %%
text_dataset = pd.read_csv('full_clean_pdfs.csv')

# %%
text_dataset.columns
# Out:
# Index(['Algo', 'Analysis', 'NN', 'Optim', 'SQL', 'Software_engineering',
#        'CIS_design', 'Software_testing', 'Project_management', 'Philosophy',
#        'Python'],
#       dtype='object')

# %%
len(text_dataset['Python'][4])
# Out:
# 48861
